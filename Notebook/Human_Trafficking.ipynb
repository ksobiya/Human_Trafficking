# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3 as sqlite

# %%
human_t=pd.read_csv('../data/The Global Dataset 14 Apr 2020.csv')
# Out:
# C:\Users\ksobi\AppData\Local\Temp\ipykernel_5704\2640791525.py:1: DtypeWarning: Columns (6,55,57) have mixed types. Specify dtype option on import or set low_memory=False.
#   human_t=pd.read_csv('../data/The Global Dataset 14 Apr 2020.csv')

# %%
human_t.head(2)
# Out:
#    By using this data you agree to the Terms of Use: https://www.ctdatacollaborative.org/terms-use  \
# 0                                                NaN
# 1                                                NaN
#
#    yearOfRegistration       Datasource  gender ageBroad majorityStatus  \
# 0                2002  Case Management  Female   18--20          Adult
# 1                2002  Case Management  Female   18--20          Adult
#
#   majorityStatusAtExploit majorityEntry citizenship  \
# 0                     -99           -99          CO
# 1                     -99           -99          CO
#
#    meansOfControlDebtBondage  ...  typeOfSexPrivateSexualServices  \
# 0                        -99  ...                             -99
# 1                        -99  ...                             -99
#
#    typeOfSexConcatenated  isAbduction  RecruiterRelationship  \
# 0                    -99          -99                    -99
# ...

# %%
human_t=human_t[['yearOfRegistration', 'gender','ageBroad', 'majorityStatus', 'majorityStatusAtExploit', 'citizenship', 'CountryOfExploitation',
                 'meansOfControlConcatenated', 'typeOfExploitConcatenated',
         'typeOfLabourConcatenated', 'typeOfSexConcatenated', 'isAbduction',
         'recruiterRelationIntimatePartner', 'recruiterRelationFriend', 'recruiterRelationFamily', 'recruiterRelationOther',
         'recruiterRelationUnknown']]

# %%
human_t.columns = ['registraion_yr', 'gender', 'age', 'majority_Status', 'majority_st_at_explot', 'citizenship','country_of_exploitation', 'means_of_control', 'exploit_type', 'labour_type', 
                  'sex_type', 'abduction', 'rctr_int_part', 'rctr_frnd', 'rctr_fmly', 'rctr_other', 'rctr_un']

# %%
human_t
# Out:
#        registraion_yr  gender     age majority_Status majority_st_at_explot  \
# 0                2002  Female  18--20           Adult                   -99
# 1                2002  Female  18--20           Adult                   -99
# 2                2002  Female  18--20           Adult                   -99
# 3                2002  Female  18--20           Adult                   -99
# 4                2002  Female  18--20           Adult                   -99
# ...               ...     ...     ...             ...                   ...
# 48796            2019  Female     -99             -99                 Adult
# 48797            2019  Female     -99             -99                 Adult
# 48798            2019  Female     -99             -99                 Adult
# 48799            2019  Female     -99             -99                 Minor
# 48800            2019  Female     -99             -99                 Adult
#
# ...

# %%
exp_t=human_t['exploit_type']

# %%
exp_t
# Out:
# 0        Sexual exploitation
# 1        Sexual exploitation
# 2        Sexual exploitation
# 3        Sexual exploitation
# 4        Sexual exploitation
#                 ...
# 48796    Sexual exploitation
# 48797    Sexual exploitation
# 48798    Sexual exploitation
# 48799    Sexual exploitation
# 48800    Sexual exploitation
# Name: exploit_type, Length: 48801, dtype: object

# %%
hu_ex=list(exp_t) # converting the column to a list by wrapping the column in list()
print(type(hu_ex))
print(hu_ex)
# Out:
# <class 'list'>
# ...

# %%
unique_exp_t=set(hu_ex)  # passing a list to a set to get unique list values, sets are enclosed in curly braces.
unique_exp_t
# Out:
# {'-99',
#  'Forced labour',
#  'Forced labour;Other',
#  'Forced labour;Sexual exploitation;Combined sexual and labour exploitation',
#  'Forced marriage',
#  'Other',
#  'Sexual exploitation',
#  'Slavery and similar practices'}

# %%
print(type(unique_exp_t))
unique_exp_t
# Out:
# <class 'set'>
# {'-99',
#  'Forced labour',
#  'Forced labour;Other',
#  'Forced labour;Sexual exploitation;Combined sexual and labour exploitation',
#  'Forced marriage',
#  'Other',
#  'Sexual exploitation',
#  'Slavery and similar practices'}

# %%
human_t['labour_type'] >('-99')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 48796    False
# 48797    False
# 48798    False
# 48799    False
# 48800    False
# Name: labour_type, Length: 48801, dtype: bool

# %%
# now we r going to mask it
human_t[human_t['labour_type'] >('-99')]
# or you can do .shape to see how many labour_type >-99
human_t[human_t['labour_type'] >('-99')].shape
# Out:
# (6249, 17)
